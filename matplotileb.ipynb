# %% [markdown]
# <a href="https://colab.research.google.com/github/anmolrajput02/node_basic_api/blob/main/matplotileb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpts=np.array([0,4])
ypts=np.array([1,200])
plt.plot(xpts,ypts)
plt.show()
